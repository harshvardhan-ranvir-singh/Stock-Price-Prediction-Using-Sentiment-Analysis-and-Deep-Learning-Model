# %% [markdown]
# # Data Source and Frequency

# %% [markdown]
# Filter news headlines for the stocks Apple, Microsoft and Amazon.

# %% [markdown]
# This notebook is divided into following parts:
# 1. Import libraries
# 2. Import data
# 3. Data filteration
# 4. Print news headline sentiments for 'aapl'

# %% [markdown]
# ## Import libraries

# %%
# For data manipulation
import pandas as pd

# %% [markdown]
# ## Import data

# %% [markdown]
# 1. news_headline_sentiments.csv
#
# Importing only a chunk of the dataset at a time as it is huge.

# %%
# Read and import news headline sentiments
chunks = pd.read_csv('news_headline_sentiments.csv', chunksize=10000)

# Create empty lists
aapl_data = []
amzn_data = []
msft_data = []

# %% [markdown]
# ## Data filteration
# Running a for loop for a chunk of dataset.
#
# Performing following Steps:
#
# 1. Remove/Drop missing values
# 2. Convert the text to lower string
# 3. Select headlines with words 'apple', 'amazon' and 'microsoft'. Append similar data.
# 4. Combine and concatenate the data
# 5. Calculate the frequency of words

# %%
for df in chunks:
    # Remove/Drop missing values
    df.dropna(inplace=True)
    # Convert the words to lower string
    df.news_headline = df.news_headline.str.lower()

    # Selects the headlines with the word 'apple' or 'aapl'
    data = df.loc[(df.news_headline.str.contains('aapl')) |
                  (df.news_headline.str.contains('apple'))]
    # Append the data into the empty aapl_data created
    aapl_data.append(data)

    # Selects the headlines with the word 'amazon' or 'amzn'
    data = df.loc[(df.news_headline.str.contains('amzn')) |
                  (df.news_headline.str.contains('amazon'))]
    # Append the data into the empty amzn_data created
    amzn_data.append(data)

    # Selects the headlines with the word 'microsoft' or 'msft'
    data = df.loc[(df.news_headline.str.contains('msft')) |
                  (df.news_headline.str.contains('microsoft'))]
    # Append the data into the empty msft_data created
    msft_data.append(data)


# Concat data together
aapl_data = pd.concat(aapl_data)
amzn_data = pd.concat(amzn_data)
msft_data = pd.concat(msft_data)

# Calculate the frequency of the news headlines
frequency = {'aapl': len(aapl_data),
             'amzn': len(amzn_data),
             'msft': len(msft_data)
             }

# Returns the frequency of the words
frequency
# Out:
# {'aapl': 2984, 'amzn': 1351, 'msft': 1792}

# %%
# Returns dataframe to downloadable csv
aapl_data.to_csv('news_headline_sentiments_aapl.csv')

# %% [markdown]
# ## Conclusion:
#
# In the upcoming notebooks, we will use the downloadable csv file containing the news headline and sentiment class for Apple(aapl).
# </span> <BR><BR>

# %% [markdown]
# ##### OOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO

# %% [markdown]
# ## Now Let's work with my datasets

# %%
import pandas as pd

# %%
# There were around 80000 rows in aapl_news_headline data.
# Then I deleted the duplicated rows by news_headline column
# Then filtered the dataframe and only took the necessary columns such as ['news_headline', 'time_stamp', 'URL']. 
# Earlier 'time_stamp' column was called 'start_time_stamp'

# %%
# !pip install vaderSentiment
# Out:
# Collecting vaderSentiment
#   Downloading vaderSentiment-3.3.2-py2.py3-none-any.whl (125 kB)
#      |████████████████████████████████| 125 kB 5.2 MB/s eta 0:00:01
# Requirement already satisfied: requests in /Users/harsh/opt/anaconda3/lib/python3.8/site-packages (from vaderSentiment) (2.25.1)
# Requirement already satisfied: idna<3,>=2.5 in /Users/harsh/opt/anaconda3/lib/python3.8/site-packages (from requests->vaderSentiment) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/harsh/opt/anaconda3/lib/python3.8/site-packages (from requests->vaderSentiment) (2020.6.20)
# Requirement already satisfied: chardet<5,>=3.0.2 in /Users/harsh/opt/anaconda3/lib/python3.8/site-packages (from requests->vaderSentiment) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/harsh/opt/anaconda3/lib/python3.8/site-packages (from requests->vaderSentiment) (1.26.3)
# Installing collected packages: vaderSentiment
# Successfully installed vaderSentiment-3.3.2

# %%
# Just playing with the vaderSentiment
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

analyzer = SentimentIntensityAnalyzer()
new_words = {
    "bear" : -2.0,
    "bull" : 2.0,
}
analyzer.lexicon.update(new_words)

analyzer.lexicon["bull"]
# Out:
# 2.0

# %%
headline = "apple 'blamed' for car crash, family sues company"
score = analyzer.polarity_scores(headline)
score
# Out:
# {'neg': 0.492, 'neu': 0.508, 'pos': 0.0, 'compound': -0.7003}

# %%
# Now let's get to the business and calculate sentiment class and sentiment score for our news headline data
def sentimenClassCalculation(negative, positive):
    
    if negative > positive:
        return -1
    elif positive > negative:
        return 1
    else:
        return 0

# %%
my_apple_dataset = pd.read_csv("aapl_news_headline.csv")

# %%
# Calculate sentiment_score
#my_apple_dataset["sentiment_score"] = my_apple_dataset["news_headline"].apply(lambda t: analyzer.polarity_scores(t)['compound'])
#my_apple_dataset.head()
# Out:
#                                        news_headline           time_stamp  \
# 0           carl icahn ups apple stake to $3 billion  2014-01-27 23:47:47
# 1       the apple mac at 30: see the evolution of a…  2014-01-27 23:47:47
# 2  apple engineers who brought mac to life get  r...  2014-01-27 23:47:47
# 3       apple takes a fresh bite into china s market  2014-01-27 23:47:47
# 4  icahn takes another $500 million bite out of a...  2014-01-27 23:47:47
#
#                                                  URL  sentiment_score
# 0  http://money.cnn.com/2014/01/22/technology/app...           0.0000
# 1  http://feeds.wired.com/c/35185/f/661457/s/3656...           0.0000
# 2  http://gadgets.ndtv.com/shortlink.aspx?article...           0.0000
# 3                                      /id/101340364           0.3182
# 4  /business/sns-rt-us-apple-icahn-20140122,0,515...           0.0000

# %%
# Calculate sentiment_class

# my_apple_dataset["sentiment_class"] = 0
# for i in range(0, len(my_apple_dataset)):
    
#     score = analyzer.polarity_scores(my_apple_dataset["news_headline"][i])
#     my_apple_dataset["sentiment_class"][i] = sentimenClassCalculation(score['neg'], score['pos'])
# Out:
# <ipython-input-9-20465f904778>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   my_apple_dataset["sentiment_class"][i] = sentimenClassCalculation(score['neg'], score['pos'])

# %%
my_apple_dataset
# Out:
#                                            news_headline           time_stamp  \
# 0               carl icahn ups apple stake to $3 billion  2014-01-27 23:47:47
# 1           the apple mac at 30: see the evolution of a…  2014-01-27 23:47:47
# 2      apple engineers who brought mac to life get  r...  2014-01-27 23:47:47
# 3           apple takes a fresh bite into china s market  2014-01-27 23:47:47
# 4      icahn takes another $500 million bite out of a...  2014-01-27 23:47:47
# ...                                                  ...                  ...
# 42278  apple 'blamed' for car crash, family sues company  2016-12-31 08:15:02
# 42279  family sues apple for losing their daughter in...  2016-12-31 08:45:01
# 42280  apple said to seek lower taxes to start manufa...  2016-12-31 11:15:01
# 42281  texas family blame apple's facetime in suit ov...  2016-12-31 14:45:01
# 42282  you don???t trust authority just because it we...  2016-12-31 19:45:01
#
#                                                      URL  sentiment_score  \
# 0      http://money.cnn.com/2014/01/22/technology/app...           0.0000
# 1      http://feeds.wired.com/c/35185/f/661457/s/3656...           0.0000
# 2      http://gadgets.ndtv.com/shortlink.aspx?article...           0.0000
# 3                                          /id/101340364           0.3182
# 4      /business/sns-rt-us-apple-icahn-20140122,0,515...           0.0000
# ...                                                  ...              ...
# 42278  /tech-news/apple-blamed-for-car-crash-family-s...          -0.7003
# 42279  http://www.news18.com/news/tech/family-sues-ap...          -0.6486
# 42280  http://profit.ndtv.com/news/gadgets/article-ap...          -0.2960
# 42281  /Technology/wireStory/texas-family-blame-apple...          -0.8225
# 42282  http://www.thehindu.com/books/books-authors/Yo...           0.6298
#
#        sentiment_class
# 0                    0
# 1                    0
# 2                    0
# 3                    1
# 4                    0
# ...                ...
# 42278               -1
# 42279               -1
# 42280               -1
# 42281               -1
# 42282                1
#
# [42283 rows x 5 columns]

# %%
#my_apple_dataset.to_csv("aapl_news_headline.csv", index=False)

# %%
# NOW FROM HERE ONWARDS I'M JUST CHECKING ROWS THAT ARE IN MY DATASET BUT NOT IN QUANTRA DATASET

# %%
# my_apple_dataset = pd.read_csv("aapl_news_headline.csv")
# my_apple_dataset
# Out:
#                                            news_headline           time_stamp  \
# 0               carl icahn ups apple stake to $3 billion  2014-01-27 23:47:47
# 1           the apple mac at 30: see the evolution of a…  2014-01-27 23:47:47
# 2      apple engineers who brought mac to life get  r...  2014-01-27 23:47:47
# 3           apple takes a fresh bite into china s market  2014-01-27 23:47:47
# 4      icahn takes another $500 million bite out of a...  2014-01-27 23:47:47
# ...                                                  ...                  ...
# 42278  apple 'blamed' for car crash, family sues company  2016-12-31 08:15:02
# 42279  family sues apple for losing their daughter in...  2016-12-31 08:45:01
# 42280  apple said to seek lower taxes to start manufa...  2016-12-31 11:15:01
# 42281  texas family blame apple's facetime in suit ov...  2016-12-31 14:45:01
# 42282  you don???t trust authority just because it we...  2016-12-31 19:45:01
#
#                                                      URL  sentiment_score  \
# 0      http://money.cnn.com/2014/01/22/technology/app...           0.0000
# 1      http://feeds.wired.com/c/35185/f/661457/s/3656...           0.0000
# 2      http://gadgets.ndtv.com/shortlink.aspx?article...           0.0000
# 3                                          /id/101340364           0.3182
# 4      /business/sns-rt-us-apple-icahn-20140122,0,515...           0.0000
# ...                                                  ...              ...
# 42278  /tech-news/apple-blamed-for-car-crash-family-s...          -0.7003
# 42279  http://www.news18.com/news/tech/family-sues-ap...          -0.6486
# 42280  http://profit.ndtv.com/news/gadgets/article-ap...          -0.2960
# 42281  /Technology/wireStory/texas-family-blame-apple...          -0.8225
# 42282  http://www.thehindu.com/books/books-authors/Yo...           0.6298
#
#        sentiment_class
# 0                    0
# 1                    0
# 2                    0
# 3                    1
# 4                    0
# ...                ...
# 42278               -1
# 42279               -1
# 42280               -1
# 42281               -1
# 42282                1
#
# [42283 rows x 5 columns]

# %%
# quantra_apple_dataset = pd.read_csv("news_headline_sentiments_aapl.csv")
# quantra_apple_dataset
# Out:
#        Unnamed: 0  Unnamed: 0.1  \
# 0              29       2012757
# 1             169       2012707
# 2             616       2012614
# 3             618       2007933
# 4             726       2011678
# ...           ...           ...
# 15308     1999722       1309707
# 15309     1999813       1309841
# 15310     1999827       1309814
# 15311     1999878       1309859
# 15312     1999906       1310042
#
#                                            news_headline  \
# 0          apple will refund at least $32.5m in app case
# 1        icahn raises apple stake, now owns $3b in stock
# 2      apple: people spent $10b in its app store in 2013
# 3      apple s mac still influencing computing, 30 ye...
# 4      new apple tv set-top box expected in first hal...
# ...                                                  ...
# 15308  govt not in favour of used apple iphones being...
# 15309  apple?s refurbished iphone plan: govt not in f...
# 15310  commerce ministry turns down apple?s proposal ...
# 15311  nirmala sitharaman may help pave way for apple...
# 15312  discussing apple's request for local sourcing ...
#
#                       time_stamp  \
# 0      2014-01-27 10:17:47-08:00
# 1      2014-01-27 10:17:47-08:00
# 2      2014-01-27 10:17:47-08:00
# 3      2014-01-27 10:17:47-08:00
# 4      2014-01-27 10:17:47-08:00
# ...                          ...
# 15308  2016-05-29 18:15:01-07:00
# 15309  2016-05-29 18:45:01-07:00
# 15310  2016-05-29 18:45:01-07:00
# 15311  2016-05-29 18:45:01-07:00
# 15312  2016-05-29 19:15:02-07:00
#
#                                                      URL  source_id  \
# 0      //www.suntimes.com/business/24974362-420/apple...       1303
# 1      //www.suntimes.com/business/25119767-420/icahn...       1303
# 2      //www.suntimes.com/business/24816093-420/apple...       1303
# 3      http://www.nbcnews.com/business/apples-mac-sti...       1288
# 4      /business/technology/la-fi-tn-new-apple-tv-fir...       1298
# ...                                                  ...        ...
# 15308  http://realtime.rediff.com/news/business/Govt-...       1502
# 15309  http://www.hindustantimes.com/business/discuss...       1243
# 15310  http://economictimes.indiatimes.com/news/econo...       1234
# 15311  http://realtime.rediff.com/news/business/Nirma...       1502
# 15312  /article/companies/discussing-apple-s-request-...       1510
#
#        sentiment_class  sentiment_scores
# 0                    0            0.0000
# 1                    0            0.0000
# 2                    0            0.0000
# 3                    0            0.0000
# 4                    0            0.0000
# ...                ...               ...
# 15308               -1           -0.3412
# 15309               -1           -0.4952
# 15310               -1           -0.1880
# 15311                1            0.4019
# 15312                0            0.0000
#
# [15313 rows x 8 columns]

# %%
# common_dataset = my_apple_dataset.merge(quantra_apple_dataset, on=["news_headline"])
# common_dataset
# Out:
#                                            news_headline         time_stamp_x  \
# 0        icahn raises apple stake, now owns $3b in stock  2014-01-27 23:47:47
# 1      let me take you back to 2007, when apple co-fo...  2014-01-27 23:47:47
# 2          apple will refund at least $32.5m in app case  2014-01-27 23:47:47
# 3      glass house + stone (or something) = apple sto...  2014-01-27 23:47:47
# 4      watch steve jobs demo the first apple mac back...  2014-01-27 23:47:47
# ...                                                  ...                  ...
# 15046  commerce minister says govt not in favour of a...  2016-05-30 06:45:01
# 15047  apple?s refurbished iphone plan: govt not in f...  2016-05-30 07:15:01
# 15048  commerce ministry turns down apple?s proposal ...  2016-05-30 07:15:01
# 15049  nirmala sitharaman may help pave way for apple...  2016-05-30 07:15:01
# 15050  discussing apple's request for local sourcing ...  2016-05-30 07:45:02
#
#                                                    URL_x  sentiment_score  \
# 0      //www.suntimes.com/business/25119767-420/icahn...           0.0000
# 1      http://financialexpress.com/news/when-the-pen-...           0.0000
# 2      //www.suntimes.com/business/24974362-420/apple...           0.0000
# 3      http://abcnews.go.com/blogs/technology/2014/01...          -0.6249
# 4      http://ibnlive.in.com/news/watch-steve-jobs-de...           0.0000
# ...                                                  ...              ...
# 15046  /Companies/lDn53REhqvhqGoIxs9MgwJ/Apples-propo...          -0.3412
# 15047  http://www.hindustantimes.com/business/discuss...          -0.3412
# 15048  http://economictimes.indiatimes.com/news/econo...           0.0000
# 15049  http://realtime.rediff.com/news/business/Nirma...           0.4019
# 15050  /article/companies/discussing-apple-s-request-...           0.0000
#
#        sentiment_class_x  Unnamed: 0  Unnamed: 0.1               time_stamp_y  \
# 0                      0         169       2012707  2014-01-27 10:17:47-08:00
# 1                      0         740       1988180  2014-01-27 10:17:47-08:00
# 2                      0          29       2012757  2014-01-27 10:17:47-08:00
# 3                     -1        1238       2007201  2014-01-27 10:17:47-08:00
# 4                      0         951       2005327  2014-01-27 10:17:47-08:00
# ...                  ...         ...           ...                        ...
# 15046                 -1     1999624       1309809  2016-05-29 18:15:01-07:00
# 15047                 -1     1999813       1309841  2016-05-29 18:45:01-07:00
# 15048                  0     1999827       1309814  2016-05-29 18:45:01-07:00
# 15049                  1     1999878       1309859  2016-05-29 18:45:01-07:00
# 15050                  0     1999906       1310042  2016-05-29 19:15:02-07:00
#
#                                                    URL_y  source_id  \
# 0      //www.suntimes.com/business/25119767-420/icahn...       1303
# 1      http://financialexpress.com/news/when-the-pen-...       1229
# 2      //www.suntimes.com/business/24974362-420/apple...       1303
# 3      http://abcnews.go.com/blogs/technology/2014/01...       1278
# 4      http://ibnlive.in.com/news/watch-steve-jobs-de...       1273
# ...                                                  ...        ...
# 15046  /Companies/lDn53REhqvhqGoIxs9MgwJ/Apples-propo...       1511
# 15047  http://www.hindustantimes.com/business/discuss...       1243
# 15048  http://economictimes.indiatimes.com/news/econo...       1234
# 15049  http://realtime.rediff.com/news/business/Nirma...       1502
# 15050  /article/companies/discussing-apple-s-request-...       1510
#
#        sentiment_class_y  sentiment_scores
# 0                      0            0.0000
# 1                      0            0.0000
# 2                      0            0.0000
# 3                     -1           -0.6249
# 4                      0            0.0000
# ...                  ...               ...
# 15046                 -1           -0.5292
# 15047                 -1           -0.4952
# 15048                 -1           -0.1880
# 15049                  1            0.4019
# 15050                  0            0.0000
#
# [15051 rows x 12 columns]

# %%
# Just Checking which news_headline data are there in my dataset, but they are not in Quantra dataset
# rows_that_are_in_my_dataset_but_not_in_quantra_dataset = my_apple_dataset[(~my_apple_dataset.news_headline.isin(common_dataset.news_headline))]
# rows_that_are_in_my_dataset_but_not_in_quantra_dataset = rows_that_are_in_my_dataset_but_not_in_quantra_dataset.reset_index(drop=True)
# rows_that_are_in_my_dataset_but_not_in_quantra_dataset
# Out:
#                                            news_headline           time_stamp  \
# 0               carl icahn ups apple stake to $3 billion  2014-01-27 23:47:47
# 1           the apple mac at 30: see the evolution of a…  2014-01-27 23:47:47
# 2      apple engineers who brought mac to life get  r...  2014-01-27 23:47:47
# 3           apple takes a fresh bite into china s market  2014-01-27 23:47:47
# 4      icahn takes another $500 million bite out of a...  2014-01-27 23:47:47
# ...                                                  ...                  ...
# 28920  apple 'blamed' for car crash, family sues company  2016-12-31 08:15:02
# 28921  family sues apple for losing their daughter in...  2016-12-31 08:45:01
# 28922  apple said to seek lower taxes to start manufa...  2016-12-31 11:15:01
# 28923  texas family blame apple's facetime in suit ov...  2016-12-31 14:45:01
# 28924  you don???t trust authority just because it we...  2016-12-31 19:45:01
#
#                                                      URL  sentiment_score  \
# 0      http://money.cnn.com/2014/01/22/technology/app...           0.0000
# 1      http://feeds.wired.com/c/35185/f/661457/s/3656...           0.0000
# 2      http://gadgets.ndtv.com/shortlink.aspx?article...           0.0000
# 3                                          /id/101340364           0.3182
# 4      /business/sns-rt-us-apple-icahn-20140122,0,515...           0.0000
# ...                                                  ...              ...
# 28920  /tech-news/apple-blamed-for-car-crash-family-s...          -0.7003
# 28921  http://www.news18.com/news/tech/family-sues-ap...          -0.6486
# 28922  http://profit.ndtv.com/news/gadgets/article-ap...          -0.2960
# 28923  /Technology/wireStory/texas-family-blame-apple...          -0.8225
# 28924  http://www.thehindu.com/books/books-authors/Yo...           0.6298
#
#        sentiment_class
# 0                    0
# 1                    0
# 2                    0
# 3                    1
# 4                    0
# ...                ...
# 28920               -1
# 28921               -1
# 28922               -1
# 28923               -1
# 28924                1
#
# [28925 rows x 5 columns]

# %%
#rows_that_are_in_my_dataset_but_not_in_quantra_dataset.to_csv("rows_that_are_in_my_dataset_but_not_in_quantra_dataset.csv", index=False)
